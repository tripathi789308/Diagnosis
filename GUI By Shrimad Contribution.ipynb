# %%
import tkinter as tk                
from tkinter import font  as tkfont


class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)

        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")

        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        
        for F in (StartPage, PageOne, PageTwo,PageThree):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame

            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        
        frame = self.frames[page_name]
        frame.tkraise()


class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        
        tk.Frame.__init__(self, parent)
        
        self.controller = controller
        
        label = tk.Label(self, text="Welcome\n To The Graphical User Interface Docter",fg="red",bg="Light Green")
        label.pack(side="top", fill="x", pady=100)
        label.config(font=("Elephant", 20))
        
        t1=tk.Text(self,height=4,width=50,fg="black",bg="yellow")
        t1.pack(side="top",pady=100)
        t1.config(font=("Elephant" , 20))
        
        c='''This is the staring page of the application.Click on next,you will be directed to next page and from there the main application starts
        .This application takes the symptoms from the user as a input and after that it predicts the change of disease which you could have.'''
        
        t1.insert(tk.END,c) 
        
        button1 = tk.Button(self, text="Proceed",command=lambda: controller.show_frame("PageOne"),fg="Blue",bg="white")
        button1.pack()
        button1.config(font=("Elephant",10))


class PageOne(tk.Frame):

    def __init__(self, parent, controller):
        
        tk.Frame.__init__(self, parent)
        
        self.controller = controller
        
        w2 = tk.Label(self, text="Disease Predictor using data science", fg="Green",bg="White")
        w2.config(font=("Elephant", 30))
        w2.pack(pady=100)
        
        w2 = tk.Label(self, text="   A Project by Shivam and Shrimad  ", fg="Green",bg="White")
        w2.config(font=("Elephant", 30))
        w2.pack(pady=100)

        button = tk.Button(self, text="Procced to next ",command=lambda: controller.show_frame("PageTwo"),fg="Red",bg="white")
        button.pack()
        button.config(font=("Elephant",10))
        
        button3=tk.Button(self, text="Back",command=lambda: controller.show_frame("StartPage"),fg="Green",bg="white")
        button3.place(x=30,y=512)
        button3.config(font=("Elephant",10))

class PageTwo(tk.Frame):

    def __init__(self, parent, controller):
        
        tk.Frame.__init__(self, parent)
        
        self.controller = controller
        
        label = tk.Label(self, text="Enter the name of the patient", font=controller.title_font,fg="Orange",bg="white")
        label.pack(side="top", fill="x", pady=10)
        label.config(font=("Elephant", 25))
       
        E1_values=tk.StringVar()
        E1=tk.Entry(self,textvariable=E1_values,fg="Green",bg="pink")
        E1.pack(side="top")
        E1.config(font=("Elephant",20))
        
        def show():
            
            a=E1_values.get()
            d=a.capitalize()
            b="            Hi "+ d +" Welcome to the app made by Shivam and Shrimad"
            T1.insert(tk.END,b)
            c="    Now "+d+" How are you feeling now or what problem do you have please select from the menu on next page "
            T2.insert(tk.END,c)

        
        button1 = tk.Button(self, text="Proceed ",command=show,fg="Green",bg="white")
        button1.pack(side="top")
        button1.config(font=("Elephant",10))
        
        T1=tk.Text(self,fg="yellow",bg="black",height=1)
        T1.pack(side="top",pady=100)
        T1.config(font=("Elephant" , 15))
        
        T2=tk.Text(self,fg="yellow",bg="black",height=1)
        T2.pack(side="top",pady=100)
        T2.config(font=("Elephant" , 15))
        
        button = tk.Button(self, text="Proceed to next",command=lambda: controller.show_frame("PageThree"),fg="Green",bg="white")
        button.place(x=395,y=550)
        button.config(font=("Elephant",10))
        
        button3=tk.Button(self, text="Back",command=lambda: controller.show_frame("PageOne"),fg="Black",bg="white")
        button3.place(x=30,y=550)
        button3.config(font=("Elephant",10))
        
class PageThree(tk.Frame):

    def __init__(self, parent, controller):
        
        tk.Frame.__init__(self, parent)
        
        self.controller = controller
        
         
        Symptom1 =tk.StringVar()
        Symptom1.set("Select the Symptoms")
        S1Lb =tk.Label(self, text="Symptom 1", fg="yellow", bg="black")
        S1Lb.place(x=200,y=10)
        S1Lb.config(font=("Elephant", 15))
        
        Symptom2 =tk.StringVar()
        Symptom2.set("Select the Symptoms")        
        S2Lb =tk.Label(self, text="Symptom 2", fg="yellow", bg="black")
        S2Lb.place(x=200,y=60)
        S2Lb.config(font=("Elephant", 15))

        Symptom3 =tk.StringVar()
        Symptom3.set("Select the symptoms")
        S3Lb =tk.Label(self, text="Symptom 3", fg="yellow", bg="black")
        S3Lb.place(x=200,y=110)
        S3Lb.config(font=("Elephant", 15))
        
        Symptom4 =tk.StringVar()
        Symptom4.set("Select the Symptoms")
        S4Lb =tk.Label(self, text="Symptom 4", fg="yellow", bg="black")
        S4Lb.place(x=200,y=160)
        S4Lb.config(font=("Elephant", 15))
        
        
        l1=[" Blue skin or lips","Swollen lips,throat and mouth,tongue, eyes or face","Dry, red and cracked skin","Tummy pain, feeling sick,vomiting or diarrhoea",
             "Pain in joints","Stiffness in joints","Swelling and redness in joints","Joint Decreased range of motion","Coughing while doing anything ","Difficulty in breathing ","Chest tightness or shortness of breath "," Whistling or squeaky sound in your chest when breat","Fever  or headache ",
            "Loss of appetite","Raised pink or red bomps","Tiredness and a general feeling of being unwell","Lost outlook","Anxiety with looking at death","Uncontrollable emotions or Sleep problems ","Weakness or irritabilit","Abdominal pain or cramps","Diarrhea","Headaches and fever","Sick or vomaiting ",
            "Muscels spams(in stomach) or stiffness all over body","Jaw cramping or trouble swallowing","Jerking or staringseizures","Headache , fever ,change in bp and high heart rate","Loose,watery stools ","Abdominal cramps and pain","Stool in blood or mucus","Bloatig and nausea" ]

        
        
        OPTIONS = l1


        S1En =tk.OptionMenu(self, Symptom1,*OPTIONS)
        S1En.place(x=600,y=10)

        S2En =tk.OptionMenu(self, Symptom2,*OPTIONS)
        S2En.place(x=600,y=60)

        S3En =tk.OptionMenu(self, Symptom3,*OPTIONS)
        S3En.place(x=600,y=110)

        S4En =tk.OptionMenu(self, Symptom4,*OPTIONS)
        S4En.place(x=600,y=160)
        
        
        label1= tk.Label(self, text="As per the symptoms selected by you,you may have ", bg="yellow",fg="Red")
        label1.place(x=140,y=210)        
        label1.config(font=("Elephant",20))
        
        
        pro={'Allergy':[' Blue skin or lips', 'Swollen lips,throat and mouth,tongue, eyes or face', 'Dry, red and cracked skin', 'Tummy pain, feeling sick,vomiting or diarrhoea'],
             'Arthritis':['Pain in joints', 'Stiffness in joints', 'Swelling and redness in joints', 'Joint Decreased range of motion'],
             'Asthma':['Coughing while doing anything ', 'Difficulty in breathing ', 'Chest tightness or shortness of breath ', ' Whistling or squeaky sound in your chest when breat'],
             'Chicken Pox':['Fever  or headache ', 'Loss of appetite', 'Raised pink or red bomps', 'Tiredness and a general feeling of being unwell'],
             'Depression':['Lost outlook', 'Anxiety with looking at death', 'Uncontrollable emotions or Sleep problems ', 'Weakness or irritabilit'],
             'Food Poision':['Abdominal pain or cramps', 'Diarrhea', 'Headaches and fever', 'Sick or vomaiting '],
             'Diarrhea':['Loose,watery stools ', 'Abdominal cramps and pain', 'Stool in blood or mucus', 'Bloatig and nausea'],
             'Tetnus':['Muscels spams(in stomach) or stiffness all over body', 'Jaw cramping or trouble swallowing', 'Jerking or staringseizures', 'Headache , fever ,change in bp and high heart rate']
            }
        
        
        T4=tk.Text(self,fg="yellow",bg="black",height=1,width=300)
        T4.place(x=0,y=310)
        T4.config(font=("Elephant" , 15))
        
        Label5=tk.Label(self,text="Here are the medicines list below which you can take",fg='green',bg='Yellow')
        Label5.config(font=("Elephant",15))
        Label5.place(x=220,y=360)
        
        T5=tk.Text(self,fg="yellow",bg="black",height=12,width=300)
        T5.place(x=0,y=410)
        T5.config(font=("Elephant" , 15))
        
       
        qote1=""" 
                1) Brompheniramine (Dimetane)
                2) Chlorpheniramine (Chlor-Trimeton)
                3) Diphenhydramine (Benadryl)
                4) Cetirizine (Zyrtec, Zyrtec-D)
                5) Clemastine (Tavist)
                6) Fexofenadine (Allegra, Allegra D)
                7) Loratadine (Claritin, Claritin D, Alavert)
                8) Antazoline/Naphazoline (Vasocon A),
                9) Ketotifen fumarate (Zaditor, Alaway, Zyrtec 
               10) Claritin Eye and Refresh Eye
               """
        
        qote2="""
                1) Zafirlukast
                2) Fluticasone and Salmeterol
                3) Flunisolide
                4) Ciclesonide
                5) Mometasone
                6) Fluticasone, Vilanterol
                7) Reslizumab
                8) Mometasone and formoterol
                9) Benralizumab
               10) Fluticasone
               """
        
        qote3="""
                1) Hoxychloroquine (Plaquenil)
                2) Leflunomide (Arava)
                3) Methotrexate (Trexall)
                4) Sulfasalazine (Azulfidine)
                5) Meinocycline (Minocin)
                6) Abatacept (Orencia)
                7) Rituximab (Rituxan)
                8) Tocilizumab (Actemra)
                9) Anakinra (Kineret)
               10) Adalimumab (Humira)
               """
        
        qote4="""
                1) Tylenol (acetaminophen)
                2) Acyclovir
                3) Valacyclovir
                4) Valtrex
                5) Zovirax
                6) Foscavir
                7) Varicella zoster immune globulin 
                8) Immune globulin intramuscular systemic
                9) Immune globulin intramuscular systemic
               10) Foscarnet systemic
               """
        
        qote5="""
                1) Cymbalta
                2) Zoloft
                3) Bupropion
                4) Lexapro
                5) Sertraline
                6) Prozac
                7) Citalopram
                8) Celexa
                9) Wellbutrin XL
               10) Fluoxetine
               """
        
        qote6="""
                1) Loperamide
                2) Bismuth Subsalicylate
                3) Chlorpromazine
                4) Metoclopramide
                """
        
        qote7="""
                1) Loperamide
                2) Lomotil
                3) Modium
                4) Atropine / diphenoxylate
                5) Imodium A-D
                6) Anti-Diarrheal
                7) Florastor
                8) Pepto-Bismol
                9) Kaopectate
               10) Lonox
               """
        
        qote8="""
                1) Methocarbamol
                2) Robaxin
                3) Diazepam
                4) Valium
                5) Tetanus immune globulin
                6) Thorazine
                7) Robaxin-750
                8) Diazepam Intensol
                9) Diastat
               10) Diastat Pediatric
               """
        
        def predict():
            c=[Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get()]
            for name,i in pro.items():
                if i==c:
                    d="You have "+name+" ,book a appointment with doctor and consult with doctor and take care of you "
                    T4.insert(tk.END,d)
                    if name=='Allergy':
                        T5.insert(tk.END,qote1)
                    elif name=='Asthma':
                        T5.insert(tk.END,qote2)
                    elif name=='Arthritis':
                        T5.insert(tk.END,qote3)  
                    elif name=='Chicken Pox':
                        T5.insert(tk.END,qote4)  
                    elif name=='Depression':
                        T5.insert(tk.END,qote5) 
                    elif name=='Food Poision':
                        T5.insert(tk.END,qote6) 
                    elif name=='Diarrhea':
                        T5.insert(tk.END,qote7)
                    else:
                        T5.insert(tk.END,qote8)
                        
                    return
            T4.insert(tk.END,"Sorry These symptoms 's diesease is not present in our dataset'")
       
    
        button2= tk.Button(self, text="Click here for prediction", fg="white",bg="Red",command=predict)
        button2.place(x=400,y=260)

        button3=tk.Button(self, text="Back",command=lambda: controller.show_frame("PageTwo"),fg="Green",bg="white")
        button3.place(x=30,y=260)
        button3.config(font=("Elephant",10))
        
if __name__ == "__main__":
    app = SampleApp()
    app.geometry('1000x850')
    app.mainloop()
